# %% [markdown]
# <a href="https://colab.research.google.com/github/kunaldash/Data-Science/blob/master/AM_709_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Upload the file from the necessary location using the command as below:

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-12228a21-2ce0-44c9-a055-3719527ee152" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-12228a21-2ce0-44c9-a055-3719527ee152">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AM 709 Analysis_Data_06092020.xlsx to AM 709 Analysis_Data_06092020.xlsx

# %% [markdown]
# Read the file using the command as below:

# %%
import io
df = pd.read_excel(io.BytesIO(uploaded['AM 709 Analysis_Data_06092020.xlsx']))
df
# Out:
#              Start Date  ... Q33_1 - Topics
# 0   2020-06-06 16:57:04  ...            NaN
# 1   2020-06-05 09:25:02  ...            NaN
# 2   2020-05-30 10:07:33  ...            NaN
# 3   2020-05-26 08:12:48  ...            NaN
# 4   2020-05-21 13:08:42  ...            NaN
# ..                  ...  ...            ...
# 563 2017-02-10 11:02:42  ...            NaN
# 564 2017-01-11 15:13:37  ...            NaN
# 565 2017-01-06 14:25:24  ...            NaN
# 566 2016-12-05 15:50:59  ...            NaN
# 567 2016-12-05 15:39:22  ...            NaN
#
# [568 rows x 126 columns]

# %%
df.head()
# Out:
#            Start Date            End Date  ...                  NDE Q33_1 - Topics
# 0 2020-06-06 16:57:04 2020-06-06 17:01:43  ...              19-3142            NaN
# 1 2020-06-05 09:25:02 2020-06-05 09:57:18  ...  4105-01-01 00:00:00            NaN
# 2 2020-05-30 10:07:33 2020-05-30 10:26:41  ...  8677-04-01 00:00:00            NaN
# 3 2020-05-26 08:12:48 2020-05-26 08:18:32  ...              24-7362            NaN
# 4 2020-05-21 13:08:42 2020-05-21 13:33:03  ...              24-4658            NaN
#
# [5 rows x 126 columns]
